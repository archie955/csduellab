# %%
import polars as pl

df = pl.read_csv("./training_data.csv")

df.head(n=3)
# Out:
# shape: (3, 28)
# ┌──────┬───────────┬──────────┬───────┬───┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ tick ┆ prev_tick ┆ assisted ┆ trade ┆ … ┆ victim_angle ┆ victim_vert ┆ victim_blin ┆ victim_weap │
# │ ---  ┆ ---       ┆ ---      ┆ ---   ┆   ┆ ---          ┆ _angle      ┆ ded         ┆ on          │
# │ i64  ┆ i64       ┆ bool     ┆ bool  ┆   ┆ f64          ┆ ---         ┆ ---         ┆ ---         │
# │      ┆           ┆          ┆       ┆   ┆              ┆ f64         ┆ bool        ┆ str         │
# ╞══════╪═══════════╪══════════╪═══════╪═══╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ 7289 ┆ 7227      ┆ false    ┆ false ┆ … ┆ 0.519405     ┆ 6.979795    ┆ false       ┆ Glock-18    │
# │ 7451 ┆ 7419      ┆ false    ┆ false ┆ … ┆ 19.013985    ┆ 6.293435    ┆ false       ┆ Glock-18    │
# │ 7543 ┆ 7483      ┆ false    ┆ true  ┆ … ┆ 1.561943     ┆ -10.512458  ┆ false       ┆ USP-S       │
# └──────┴───────────┴──────────┴───────┴───┴──────────────┴─────────────┴─────────────┴─────────────┘

# %%
def weapon_parse(w):
    if w in {"AK-47", "M4A4", "AUG", "SCAR-20", "M4A1", "FAMAS", "Galil AR", "SG 553"}:
        return "Rifle"
    elif w in {
        "P2000",
        "USP-S",
        "Glock-18",
        "P250",
        "Five-SeveN",
        "Tec-9",
        "CZ75-Auto",
        "CZ75 Auto",
        "Dual Berettas",
        "Desert Eagle",
        "R8 Revolver",
    }:
        return "Pistol"
    elif w in {"Nova", "XM1014", "MAG-7", "Sawed-Off"}:
        return "Shotgun"
    elif w in {"MP9", "MAC-10", "PP-Bizon", "MP7", "UMP-45", "P90", "MP5-SD"}:
        return "SMG"
    elif w in {"SSG 08", "AWP", "SCAR-20", "G3SG1"}:
        return "Sniper"
    elif w in {"M249", "Negev"}:
        return "Machine Gun"
    elif w in {
        "HE Grenade",
        "Molotov",
        "Incendiary Grenade",
        "Smoke Grenade",
        "Decoy Grenade",
        "Flashbang",
        "Flash Grenade",
    }:
        return "Grenade"
    elif w in {"Knife", "Zeus x27", "C4"}:
        return "Melee"
    else:
        return w

# %%
df = df.with_columns(
    pl.col("attacker_weapon").map_elements(weapon_parse, return_dtype=pl.String)
)
df = df.with_columns(
    pl.col("victim_weapon").map_elements(weapon_parse, return_dtype=pl.String)
)
df.select("attacker_weapon").unique()
df.select("victim_weapon").unique()
# Out:
# shape: (7, 1)
# ┌───────────────┐
# │ victim_weapon │
# │ ---           │
# │ str           │
# ╞═══════════════╡
# │ Shotgun       │
# │ Grenade       │
# │ SMG           │
# │ Pistol        │
# │ Rifle         │
# │ Melee         │
# │ Sniper        │
# └───────────────┘

# %%
cols = []
for key in df.collect_schema():
    if key not in {"tick", "prev_tick", "attacker_weapon", "victim_weapon"}:
        cols.append(key)
print(cols)
# Out:
# ['assisted', 'trade', 'distance', 'attacker_vel', 'attacker_vel_dir', 'attacker_vz', 'attacker_side', 'attacker_hp', 'attacker_helmet', 'attacker_armor', 'attacker_spotted', 'attacker_angle', 'attacker_vert_angle', 'attacker_blinded', 'victim_vel', 'victim_vel_dir', 'victim_vz', 'victim_hp', 'victim_helmet', 'victim_armor', 'victim_spotted', 'victim_angle', 'victim_vert_angle', 'victim_blinded']

# %%
cols = []
for key in df.collect_schema():
    cols.append(key)
print(cols)
# Out:
# ['tick', 'prev_tick', 'assisted', 'trade', 'distance', 'attacker_vel', 'attacker_vel_dir', 'attacker_vz', 'attacker_side', 'attacker_hp', 'attacker_helmet', 'attacker_armor', 'attacker_spotted', 'attacker_angle', 'attacker_vert_angle', 'attacker_blinded', 'attacker_weapon', 'victim_vel', 'victim_vel_dir', 'victim_vz', 'victim_hp', 'victim_helmet', 'victim_armor', 'victim_spotted', 'victim_angle', 'victim_vert_angle', 'victim_blinded', 'victim_weapon']

# %%
for col in cols:
    df = df.rename({col: col.replace("attacker", "player_1")})
df.head(n=3)
# Out:
# shape: (3, 28)
# ┌──────┬───────────┬──────────┬───────┬───┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ tick ┆ prev_tick ┆ assisted ┆ trade ┆ … ┆ victim_angle ┆ victim_vert ┆ victim_blin ┆ victim_weap │
# │ ---  ┆ ---       ┆ ---      ┆ ---   ┆   ┆ ---          ┆ _angle      ┆ ded         ┆ on          │
# │ i64  ┆ i64       ┆ bool     ┆ bool  ┆   ┆ f64          ┆ ---         ┆ ---         ┆ ---         │
# │      ┆           ┆          ┆       ┆   ┆              ┆ f64         ┆ bool        ┆ str         │
# ╞══════╪═══════════╪══════════╪═══════╪═══╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ 7289 ┆ 7227      ┆ false    ┆ false ┆ … ┆ 0.519405     ┆ 6.979795    ┆ false       ┆ Pistol      │
# │ 7451 ┆ 7419      ┆ false    ┆ false ┆ … ┆ 19.013985    ┆ 6.293435    ┆ false       ┆ Pistol      │
# │ 7543 ┆ 7483      ┆ false    ┆ true  ┆ … ┆ 1.561943     ┆ -10.512458  ┆ false       ┆ Pistol      │
# └──────┴───────────┴──────────┴───────┴───┴──────────────┴─────────────┴─────────────┴─────────────┘

# %%
for col in cols:
    df = df.rename({col: col.replace("victim", "player_2")})
df.head(n=3)
# Out:
# shape: (3, 28)
# ┌──────┬───────────┬──────────┬───────┬───┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ tick ┆ prev_tick ┆ assisted ┆ trade ┆ … ┆ player_2_ang ┆ player_2_ve ┆ player_2_bl ┆ player_2_we │
# │ ---  ┆ ---       ┆ ---      ┆ ---   ┆   ┆ le           ┆ rt_angle    ┆ inded       ┆ apon        │
# │ i64  ┆ i64       ┆ bool     ┆ bool  ┆   ┆ ---          ┆ ---         ┆ ---         ┆ ---         │
# │      ┆           ┆          ┆       ┆   ┆ f64          ┆ f64         ┆ bool        ┆ str         │
# ╞══════╪═══════════╪══════════╪═══════╪═══╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ 7289 ┆ 7227      ┆ false    ┆ false ┆ … ┆ 0.519405     ┆ 6.979795    ┆ false       ┆ Pistol      │
# │ 7451 ┆ 7419      ┆ false    ┆ false ┆ … ┆ 19.013985    ┆ 6.293435    ┆ false       ┆ Pistol      │
# │ 7543 ┆ 7483      ┆ false    ┆ true  ┆ … ┆ 1.561943     ┆ -10.512458  ┆ false       ┆ Pistol      │
# └──────┴───────────┴──────────┴───────┴───┴──────────────┴─────────────┴─────────────┴─────────────┘

# %%
df = df.drop("assisted")
df = df.drop("trade")
df.head(n=3)
# Out:
# shape: (3, 26)
# ┌──────┬───────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ tick ┆ prev_tick ┆ distance   ┆ player_1_v ┆ … ┆ player_2_a ┆ player_2_v ┆ player_2_ ┆ player_2_ │
# │ ---  ┆ ---       ┆ ---        ┆ el         ┆   ┆ ngle       ┆ ert_angle  ┆ blinded   ┆ weapon    │
# │ i64  ┆ i64       ┆ f64        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │      ┆           ┆            ┆ f64        ┆   ┆ f64        ┆ f64        ┆ bool      ┆ str       │
# ╞══════╪═══════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 7289 ┆ 7227      ┆ 1086.24701 ┆ 133.026927 ┆ … ┆ 0.519405   ┆ 6.979795   ┆ false     ┆ Pistol    │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7451 ┆ 7419      ┆ 1167.66573 ┆ 59.749871  ┆ … ┆ 19.013985  ┆ 6.293435   ┆ false     ┆ Pistol    │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7543 ┆ 7483      ┆ 701.564725 ┆ 231.370504 ┆ … ┆ 1.561943   ┆ -10.512458 ┆ false     ┆ Pistol    │
# └──────┴───────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
new_df = df.clone()
new_df.head(n=3)
# Out:
# shape: (3, 26)
# ┌──────┬───────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ tick ┆ prev_tick ┆ distance   ┆ player_1_v ┆ … ┆ player_2_a ┆ player_2_v ┆ player_2_ ┆ player_2_ │
# │ ---  ┆ ---       ┆ ---        ┆ el         ┆   ┆ ngle       ┆ ert_angle  ┆ blinded   ┆ weapon    │
# │ i64  ┆ i64       ┆ f64        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │      ┆           ┆            ┆ f64        ┆   ┆ f64        ┆ f64        ┆ bool      ┆ str       │
# ╞══════╪═══════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 7289 ┆ 7227      ┆ 1086.24701 ┆ 133.026927 ┆ … ┆ 0.519405   ┆ 6.979795   ┆ false     ┆ Pistol    │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7451 ┆ 7419      ┆ 1167.66573 ┆ 59.749871  ┆ … ┆ 19.013985  ┆ 6.293435   ┆ false     ┆ Pistol    │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7543 ┆ 7483      ┆ 701.564725 ┆ 231.370504 ┆ … ┆ 1.561943   ┆ -10.512458 ┆ false     ┆ Pistol    │
# └──────┴───────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
cols = []
for key in new_df.collect_schema():
    cols.append(key)
for col in cols:
    new_df = new_df.rename({col: col.replace("player_1", "temporary")})
new_df.head(n=3)
# Out:
# shape: (3, 26)
# ┌──────┬───────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ tick ┆ prev_tick ┆ distance   ┆ temporary_ ┆ … ┆ player_2_a ┆ player_2_v ┆ player_2_ ┆ player_2_ │
# │ ---  ┆ ---       ┆ ---        ┆ vel        ┆   ┆ ngle       ┆ ert_angle  ┆ blinded   ┆ weapon    │
# │ i64  ┆ i64       ┆ f64        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │      ┆           ┆            ┆ f64        ┆   ┆ f64        ┆ f64        ┆ bool      ┆ str       │
# ╞══════╪═══════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 7289 ┆ 7227      ┆ 1086.24701 ┆ 133.026927 ┆ … ┆ 0.519405   ┆ 6.979795   ┆ false     ┆ Pistol    │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7451 ┆ 7419      ┆ 1167.66573 ┆ 59.749871  ┆ … ┆ 19.013985  ┆ 6.293435   ┆ false     ┆ Pistol    │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7543 ┆ 7483      ┆ 701.564725 ┆ 231.370504 ┆ … ┆ 1.561943   ┆ -10.512458 ┆ false     ┆ Pistol    │
# └──────┴───────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
cols = []
for key in new_df.collect_schema():
    cols.append(key)
for col in cols:
    new_df = new_df.rename({col: col.replace("player_2", "player_1")})
new_df.head(n=3)
# Out:
# shape: (3, 26)
# ┌──────┬───────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ tick ┆ prev_tick ┆ distance   ┆ temporary_ ┆ … ┆ player_1_a ┆ player_1_v ┆ player_1_ ┆ player_1_ │
# │ ---  ┆ ---       ┆ ---        ┆ vel        ┆   ┆ ngle       ┆ ert_angle  ┆ blinded   ┆ weapon    │
# │ i64  ┆ i64       ┆ f64        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │      ┆           ┆            ┆ f64        ┆   ┆ f64        ┆ f64        ┆ bool      ┆ str       │
# ╞══════╪═══════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 7289 ┆ 7227      ┆ 1086.24701 ┆ 133.026927 ┆ … ┆ 0.519405   ┆ 6.979795   ┆ false     ┆ Pistol    │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7451 ┆ 7419      ┆ 1167.66573 ┆ 59.749871  ┆ … ┆ 19.013985  ┆ 6.293435   ┆ false     ┆ Pistol    │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7543 ┆ 7483      ┆ 701.564725 ┆ 231.370504 ┆ … ┆ 1.561943   ┆ -10.512458 ┆ false     ┆ Pistol    │
# └──────┴───────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
cols = []
for key in new_df.collect_schema():
    cols.append(key)
for col in cols:
    new_df = new_df.rename({col: col.replace("temporary", "player_2")})
new_df.head(n=3)
# Out:
# shape: (3, 26)
# ┌──────┬───────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ tick ┆ prev_tick ┆ distance   ┆ player_2_v ┆ … ┆ player_1_a ┆ player_1_v ┆ player_1_ ┆ player_1_ │
# │ ---  ┆ ---       ┆ ---        ┆ el         ┆   ┆ ngle       ┆ ert_angle  ┆ blinded   ┆ weapon    │
# │ i64  ┆ i64       ┆ f64        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │      ┆           ┆            ┆ f64        ┆   ┆ f64        ┆ f64        ┆ bool      ┆ str       │
# ╞══════╪═══════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 7289 ┆ 7227      ┆ 1086.24701 ┆ 133.026927 ┆ … ┆ 0.519405   ┆ 6.979795   ┆ false     ┆ Pistol    │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7451 ┆ 7419      ┆ 1167.66573 ┆ 59.749871  ┆ … ┆ 19.013985  ┆ 6.293435   ┆ false     ┆ Pistol    │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7543 ┆ 7483      ┆ 701.564725 ┆ 231.370504 ┆ … ┆ 1.561943   ┆ -10.512458 ┆ false     ┆ Pistol    │
# └──────┴───────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
df = df.with_columns(pl.lit(True).alias("player_1_win"))
df.head(n=3)
# Out:
# shape: (3, 27)
# ┌──────┬───────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ tick ┆ prev_tick ┆ distance   ┆ player_1_v ┆ … ┆ player_2_v ┆ player_2_b ┆ player_2_ ┆ player_1_ │
# │ ---  ┆ ---       ┆ ---        ┆ el         ┆   ┆ ert_angle  ┆ linded     ┆ weapon    ┆ win       │
# │ i64  ┆ i64       ┆ f64        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │      ┆           ┆            ┆ f64        ┆   ┆ f64        ┆ bool       ┆ str       ┆ bool      │
# ╞══════╪═══════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 7289 ┆ 7227      ┆ 1086.24701 ┆ 133.026927 ┆ … ┆ 6.979795   ┆ false      ┆ Pistol    ┆ true      │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7451 ┆ 7419      ┆ 1167.66573 ┆ 59.749871  ┆ … ┆ 6.293435   ┆ false      ┆ Pistol    ┆ true      │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7543 ┆ 7483      ┆ 701.564725 ┆ 231.370504 ┆ … ┆ -10.512458 ┆ false      ┆ Pistol    ┆ true      │
# └──────┴───────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
new_df = new_df.with_columns(pl.lit(False).alias("player_1_win"))
new_df.head(n=3)
# Out:
# shape: (3, 27)
# ┌──────┬───────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ tick ┆ prev_tick ┆ distance   ┆ player_2_v ┆ … ┆ player_1_v ┆ player_1_b ┆ player_1_ ┆ player_1_ │
# │ ---  ┆ ---       ┆ ---        ┆ el         ┆   ┆ ert_angle  ┆ linded     ┆ weapon    ┆ win       │
# │ i64  ┆ i64       ┆ f64        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │      ┆           ┆            ┆ f64        ┆   ┆ f64        ┆ bool       ┆ str       ┆ bool      │
# ╞══════╪═══════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 7289 ┆ 7227      ┆ 1086.24701 ┆ 133.026927 ┆ … ┆ 6.979795   ┆ false      ┆ Pistol    ┆ false     │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7451 ┆ 7419      ┆ 1167.66573 ┆ 59.749871  ┆ … ┆ 6.293435   ┆ false      ┆ Pistol    ┆ false     │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7543 ┆ 7483      ┆ 701.564725 ┆ 231.370504 ┆ … ┆ -10.512458 ┆ false      ┆ Pistol    ┆ false     │
# └──────┴───────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
def side(s):
    if s == "t":
        return "ct"
    elif s == "ct":
        return "t"
    else:
        return "ERROR"

# %%
new_df = new_df.with_columns(
    (pl.col("player_2_side").map_elements(side, return_dtype=pl.String)).alias(
        "player_1_side"
    )
)
new_df = new_df.drop("player_2_side")
new_df.head(n=3)
# Out:
# shape: (3, 27)
# ┌──────┬───────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ tick ┆ prev_tick ┆ distance   ┆ player_2_v ┆ … ┆ player_1_b ┆ player_1_w ┆ player_1_ ┆ player_1_ │
# │ ---  ┆ ---       ┆ ---        ┆ el         ┆   ┆ linded     ┆ eapon      ┆ win       ┆ side      │
# │ i64  ┆ i64       ┆ f64        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │      ┆           ┆            ┆ f64        ┆   ┆ bool       ┆ str        ┆ bool      ┆ str       │
# ╞══════╪═══════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 7289 ┆ 7227      ┆ 1086.24701 ┆ 133.026927 ┆ … ┆ false      ┆ Pistol     ┆ false     ┆ t         │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7451 ┆ 7419      ┆ 1167.66573 ┆ 59.749871  ┆ … ┆ false      ┆ Pistol     ┆ false     ┆ t         │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7543 ┆ 7483      ┆ 701.564725 ┆ 231.370504 ┆ … ┆ false      ┆ Pistol     ┆ false     ┆ ct        │
# └──────┴───────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
total_df = pl.concat([df, new_df], how="diagonal")
total_df.head(n=3)
# Out:
# shape: (3, 27)
# ┌──────┬───────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ tick ┆ prev_tick ┆ distance   ┆ player_1_v ┆ … ┆ player_2_v ┆ player_2_b ┆ player_2_ ┆ player_1_ │
# │ ---  ┆ ---       ┆ ---        ┆ el         ┆   ┆ ert_angle  ┆ linded     ┆ weapon    ┆ win       │
# │ i64  ┆ i64       ┆ f64        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │      ┆           ┆            ┆ f64        ┆   ┆ f64        ┆ bool       ┆ str       ┆ bool      │
# ╞══════╪═══════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 7289 ┆ 7227      ┆ 1086.24701 ┆ 133.026927 ┆ … ┆ 6.979795   ┆ false      ┆ Pistol    ┆ true      │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7451 ┆ 7419      ┆ 1167.66573 ┆ 59.749871  ┆ … ┆ 6.293435   ┆ false      ┆ Pistol    ┆ true      │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7543 ┆ 7483      ┆ 701.564725 ┆ 231.370504 ┆ … ┆ -10.512458 ┆ false      ┆ Pistol    ┆ true      │
# └──────┴───────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
def weapon_check(target):
    def check(weapon):
        return weapon == target
    return check

# %%
total_df = total_df.with_columns(
    (pl.col("player_1_weapon") == "Rifle").alias("player_1_rifle")
)
total_df = total_df.with_columns(
    (pl.col("player_1_weapon") == "Pistol").alias("player_1_pistol")
)
total_df = total_df.with_columns(
    (pl.col("player_1_weapon") == "Sniper").alias("player_1_sniper")
)
total_df = total_df.with_columns(
    (pl.col("player_1_weapon") == "Melee").alias("player_1_melee")
)
total_df = total_df.with_columns(
    (pl.col("player_1_weapon") == "SMG").alias("player_1_smg")
)
total_df = total_df.with_columns(
    (pl.col("player_1_weapon") == "Grenade").alias("player_1_grenade")
)
total_df = total_df.with_columns(
    (pl.col("player_1_weapon") == "Shotgun").alias("player_1_shotgun")
)
total_df = total_df.with_columns(
    (pl.col("player_2_weapon") == "Rifle").alias("player_2_rifle")
)
total_df = total_df.with_columns(
    (pl.col("player_2_weapon") == "Pistol").alias("player_2_pistol")
)
total_df = total_df.with_columns(
    (pl.col("player_2_weapon") == "Sniper").alias("player_2_sniper")
)
total_df = total_df.with_columns(
    (pl.col("player_2_weapon") == "Melee").alias("player_2_melee")
)
total_df = total_df.with_columns(
    (pl.col("player_2_weapon") == "SMG").alias("player_2_smg")
)
total_df = total_df.with_columns(
    (pl.col("player_2_weapon") == "Grenade").alias("player_2_grenade")
)
total_df = total_df.with_columns(
    (pl.col("player_2_weapon") == "Shotgun").alias("player_2_shotgun")
)

# %%
for col, dtype in total_df.schema.items():
    print(col, dtype)
# Out:
# tick Int64
# prev_tick Int64
# distance Float64
# player_1_vel Float64
# player_1_vel_dir Float64
# player_1_vz Float64
# player_1_side String
# player_1_hp Int64
# player_1_helmet Boolean
# player_1_armor Boolean
# player_1_spotted Boolean
# player_1_angle Float64
# player_1_vert_angle Float64
# player_1_blinded Boolean
# player_1_weapon String
# player_2_vel Float64
# player_2_vel_dir Float64
# player_2_vz Float64
# player_2_hp Int64
# player_2_helmet Boolean
# player_2_armor Boolean
# player_2_spotted Boolean
# player_2_angle Float64
# player_2_vert_angle Float64
# player_2_blinded Boolean
# player_2_weapon String
# player_1_win Boolean
# player_1_rifle Boolean
# player_1_pistol Boolean
# player_1_sniper Boolean
# player_1_melee Boolean
# player_1_smg Boolean
# player_1_grenade Boolean
# player_1_shotgun Boolean
# player_2_rifle Boolean
# player_2_pistol Boolean
# player_2_sniper Boolean
# player_2_melee Boolean
# player_2_smg Boolean
# player_2_grenade Boolean
# player_2_shotgun Boolean

# %%
total_df.count()
# Out:
# shape: (1, 41)
# ┌────────┬───────────┬──────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ tick   ┆ prev_tick ┆ distance ┆ player_1_v ┆ … ┆ player_2_m ┆ player_2_s ┆ player_2_ ┆ player_2_ │
# │ ---    ┆ ---       ┆ ---      ┆ el         ┆   ┆ elee       ┆ mg         ┆ grenade   ┆ shotgun   │
# │ u32    ┆ u32       ┆ u32      ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │        ┆           ┆          ┆ u32        ┆   ┆ u32        ┆ u32        ┆ u32       ┆ u32       │
# ╞════════╪═══════════╪══════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 236982 ┆ 236982    ┆ 236982   ┆ 236982     ┆ … ┆ 236982     ┆ 236982     ┆ 236982    ┆ 236982    │
# └────────┴───────────┴──────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
total_df.row(0)
# Out:
# (7289,
#  7227,
#  1086.2470139715895,
#  133.02692682436603,
#  19.763669516750838,
#  0.0,
#  'ct',
#  90,
#  False,
#  True,
#  True,
#  0.12389741580386726,
#  -6.9797950448896975,
#  False,
#  'Pistol',
#  40.98558150590966,
#  197.72035879761643,
#  0.0,
#  72,
#  False,
#  True,
#  True,
#  0.5194052283038673,
#  6.9797950448896975,
#  False,
#  'Pistol',
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False)

# %%
total_df.row(118491)
# Out:
# (7289,
#  7227,
#  1086.2470139715895,
#  40.98558150590966,
#  197.72035879761643,
#  0.0,
#  't',
#  72,
#  False,
#  True,
#  True,
#  0.5194052283038673,
#  6.9797950448896975,
#  False,
#  'Pistol',
#  133.02692682436603,
#  19.763669516750838,
#  0.0,
#  90,
#  False,
#  True,
#  True,
#  0.12389741580386726,
#  -6.9797950448896975,
#  False,
#  'Pistol',
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False)

# %%
total_df.head(n=3)
# Out:
# shape: (3, 41)
# ┌──────┬───────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ tick ┆ prev_tick ┆ distance   ┆ player_1_v ┆ … ┆ player_2_m ┆ player_2_s ┆ player_2_ ┆ player_2_ │
# │ ---  ┆ ---       ┆ ---        ┆ el         ┆   ┆ elee       ┆ mg         ┆ grenade   ┆ shotgun   │
# │ i64  ┆ i64       ┆ f64        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │      ┆           ┆            ┆ f64        ┆   ┆ bool       ┆ bool       ┆ bool      ┆ bool      │
# ╞══════╪═══════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 7289 ┆ 7227      ┆ 1086.24701 ┆ 133.026927 ┆ … ┆ false      ┆ false      ┆ false     ┆ false     │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7451 ┆ 7419      ┆ 1167.66573 ┆ 59.749871  ┆ … ┆ false      ┆ false      ┆ false     ┆ false     │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7543 ┆ 7483      ┆ 701.564725 ┆ 231.370504 ┆ … ┆ false      ┆ false      ┆ false     ┆ false     │
# └──────┴───────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
total_df = total_df.drop("player_1_weapon")
total_df = total_df.drop("player_2_weapon")
total_df.head(n=3)
# Out:
# shape: (3, 39)
# ┌──────┬───────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ tick ┆ prev_tick ┆ distance   ┆ player_1_v ┆ … ┆ player_2_m ┆ player_2_s ┆ player_2_ ┆ player_2_ │
# │ ---  ┆ ---       ┆ ---        ┆ el         ┆   ┆ elee       ┆ mg         ┆ grenade   ┆ shotgun   │
# │ i64  ┆ i64       ┆ f64        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │      ┆           ┆            ┆ f64        ┆   ┆ bool       ┆ bool       ┆ bool      ┆ bool      │
# ╞══════╪═══════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 7289 ┆ 7227      ┆ 1086.24701 ┆ 133.026927 ┆ … ┆ false      ┆ false      ┆ false     ┆ false     │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7451 ┆ 7419      ┆ 1167.66573 ┆ 59.749871  ┆ … ┆ false      ┆ false      ┆ false     ┆ false     │
# │      ┆           ┆ 4          ┆            ┆   ┆            ┆            ┆           ┆           │
# │ 7543 ┆ 7483      ┆ 701.564725 ┆ 231.370504 ┆ … ┆ false      ┆ false      ┆ false     ┆ false     │
# └──────┴───────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
total_df.write_csv("./final_model_data.csv", separator=",", include_header=True)
